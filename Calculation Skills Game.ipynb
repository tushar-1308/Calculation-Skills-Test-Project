# %%
import random
import time

class ArithmeticGame:
    def __init__(self, num_questions):
        self.num_questions = num_questions
    def generate_questions(self):
        operand_1 = random.randint(11,40)
        operand_2 = random.randint(11,40)
        operator = random.choice(['+','-','*','//'])
        if operator == '+':
            answer = operand_1 + operand_2
        elif operator == '-':
            answer = operand_1 - operand_2
        elif operator == '*':
            answer = operand_1 * operand_2
        elif operator == '//':
            answer = operand_1 // operand_2
        elif operator == '%':
            answer = operand_1 % operand_2
        question = str(operand_1) + ' ' + operator + ' ' + str(operand_2)
        return question, answer
    def play_game(self):
        num_correct = 0
        start_time = time.time()
        for i in range(self.num_questions):
            print('Question '+str(i+1)+':')
            question, answer = self.generate_questions()
            print(question)
            user_answer = int(input('What is your answer?: '))
            if user_answer == answer:
                num_correct = num_correct + 1
                print('You are correct')
                print()
            else:
                print('You are wrong. The correct answer is '+str(answer))
                print()
        end_time=time.time()
        print('You got '+str(num_correct)+' answers correct.')
        print('You used {0:.3f} seconds.'.format(end_time-start_time))
        
        
new_game = ArithmeticGame(10)
new_game.play_game()
# Out:
# Question 1:
# 18 * 39
# What is your answer?: 622
# You are wrong. The correct answer is 702
#
# Question 2:
# 27 * 35
# What is your answer?: 645
# You are wrong. The correct answer is 945
#
# Question 3:
# 33 - 26
# What is your answer?: 7
# You are correct
#
# Question 4:
# 30 - 18
# What is your answer?: 12
# You are correct
#
# Question 5:
# 29 + 18
# What is your answer?: 37
# You are wrong. The correct answer is 47
#
# Question 6:
# 26 - 37
# What is your answer?: -11
# You are correct
#
# Question 7:
# 24 - 34
# What is your answer?: -10
# You are correct
#
# Question 8:
# 36 * 38
# What is your answer?: 1368
# You are correct
#
# Question 9:
# 21 * 24
# What is your answer?: 504
# You are correct
#
# Question 10:
# 29 - 25
# What is your answer?: 4
# You are correct
#
# You got 7 answers correct.
# You used 92.108 seconds.
